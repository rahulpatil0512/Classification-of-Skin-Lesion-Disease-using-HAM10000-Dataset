# %%
from numpy.random import seed
seed(1)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image
from sklearn.preprocessing import label_binarize
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 from numpy.random import seed
#       2 seed(1)
# ----> 3 import matplotlib.pyplot as plt
#       4 import numpy as np
#       5 import pandas as pd
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
from numpy.random import seed
seed(1)
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image
from sklearn.preprocessing import label_binarize
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score

# %%
import itertools

from tensorflow import keras
from tensorflow.keras.applications import ResNet50, Xception
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Activation,Dense, Dropout, Flatten, Conv2D, MaxPool2D,AveragePooling2D,GlobalMaxPooling2D
from tensorflow.keras import backend as K
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.layers import *
    
    
    
    
    
#from keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras import utils
utils.to_categorical # convert to one-hot-encoding
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam, SGD
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping

np.random.seed(123)

# %%
import itertools

import keras
from keras.applications import ResNet50, Xception
from keras.models import Sequential, Model, Input
from keras.layers import Activation,Dense, Dropout, Flatten, Conv2D, MaxPool2D,AveragePooling2D,GlobalMaxPooling2D
from keras import backend as K
from keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.python.keras.models import Input
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-22-90c2b13b0151> in <module>
#       2
#       3 import keras
# ----> 4 from keras.applications import ResNet50, Xception
#       5 from keras.models import Sequential, Model, Input
#       6 from keras.layers import Activation,Dense, Dropout, Flatten, Conv2D, MaxPool2D,AveragePooling2D,GlobalMaxPooling2D
#
# ImportError: cannot import name 'ResNet50'

# %%
import itertools

import keras
from keras.applications import ResNet50, Xception
from keras.models import Sequential, Model
from keras.layers import Activation,Dense, Dropout, Flatten, Conv2D, MaxPool2D,AveragePooling2D,GlobalMaxPooling2D
from keras import backend as K
from keras.wrappers.scikit_learn import KerasClassifier
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-23-85ee9f0f184b> in <module>
#       2
#       3 import keras
# ----> 4 from keras.applications import ResNet50, Xception
#       5 from keras.models import Sequential, Model
#       6 from keras.layers import Activation,Dense, Dropout, Flatten, Conv2D, MaxPool2D,AveragePooling2D,GlobalMaxPooling2D
#
# ImportError: cannot import name 'ResNet50'

# %%
 
#from keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import BatchNormalization
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras import regularizers
from keras.optimizers import Adam, SGD
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau, EarlyStopping

np.random.seed(123)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-24-efccf50369cf> in <module>
#       1 #from keras.layers.normalization import BatchNormalization
#       2 from tensorflow.keras.layers import BatchNormalization
# ----> 3 from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
#       4 from keras import regularizers
#       5 from keras.optimizers import Adam, SGD
#
# ModuleNotFoundError: No module named 'keras.utils.np_utils'

# %%
import tensorflow as tf

# %%
def basic_EDA(df):
    size = df.shape
    sum_duplicates = df.duplicated().sum()
    sum_null = df.isnull().sum().sum()
    is_NaN = df. isnull()
    row_has_NaN = is_NaN. any(axis=1)
    rows_with_NaN = df[row_has_NaN]
    count_NaN_rows = rows_with_NaN.shape
    return print("Number of Samples: %d,\nNumber of Features: %d,\nDuplicated Entries: %d,\nNull Entries: %d,\nNumber of Rows with Null Entries: %d %.1f%%" %(size[0],size[1], sum_duplicates, sum_null,count_NaN_rows[0],(count_NaN_rows[0] / df.shape[0])*100))

def summary_table(df):
    summary = pd.DataFrame(df.dtypes,columns=['dtypes'])
    summary = summary.reset_index()
    summary['Name'] = summary['index']
    summary = summary[['Name','dtypes']]
    summary['Missing'] = df.isnull().sum().values    
    summary['Uniques'] = df.nunique().values
    return summary

def countplot(df, x, x_axis_title,y_axys_title, plot_title):
    plt.figure(figsize=(20,8))
    sns.set(style="ticks", font_scale = 1)
    ax = sns.countplot(data = df,x=x,order = df[x].value_counts().index,palette="Blues_d")
    sns.despine(top=True, right=True, left=True, bottom=False)
    plt.xticks(rotation=0,fontsize = 12)
    ax.set_xlabel(x_axis_title,fontsize = 14,weight = 'bold')
    ax.set_ylabel(y_axys_title,fontsize = 14,weight = 'bold')
    plt.title(plot_title, fontsize = 16,weight = 'bold')

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-27-d5df0069828e> in <module>
# ----> 1 from google.colab import drive
#       2 drive.mount('/content/drive')
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
#Lesion Dictionary
lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

base_skin_dir = os.path.join('..', 'input')
#Dictionary for Image Names
imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x for x in glob(os.path.join('E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG','*', '*.jpg'))}
#Read File csv
skin_df = pd.read_csv('E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_metadata')
#Create useful Columns - Images Path, Lesion Type and Lesion Categorical Code
skin_df['path'] = skin_df['image_id'].map(imageid_path_dict.get)
skin_df['cell_type'] = skin_df['dx'].map(lesion_type_dict.get) 
skin_df['cell_type_idx'] = pd.Categorical(skin_df['cell_type']).codes

# %%
imageid_path_dict
# Out:
# {'ISIC_0024306': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024306.jpg',
#  'ISIC_0024307': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024307.jpg',
#  'ISIC_0024308': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024308.jpg',
#  'ISIC_0024309': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024309.jpg',
#  'ISIC_0024310': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024310.jpg',
#  'ISIC_0024311': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024311.jpg',
#  'ISIC_0024312': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024312.jpg',
#  'ISIC_0024313': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024313.jpg',
#  'ISIC_0024314': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024314.jpg',
#  'ISIC_0024315': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024315.jpg',
#  'ISIC_0024316': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024316.jpg',
#  'ISIC_0024317': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024317.jpg',
#  'ISIC_0024318': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024318.jpg',
#  'ISIC_0024319': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024319.jpg',
#  'ISIC_0024320': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024320.jpg',
#  'ISIC_0024321': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024321.jpg',
#  'ISIC_0024322': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024322.jpg',
#  'ISIC_0024323': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024323.jpg',
#  'ISIC_0024324': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024324.jpg',
#  'ISIC_0024325': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024325.jpg',
#  'ISIC_0024326': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024326.jpg',
#  'ISIC_0024327': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024327.jpg',
#  'ISIC_0024328': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024328.jpg',
#  'ISIC_0024329': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024329.jpg',
#  'ISIC_0024330': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024330.jpg',
#  'ISIC_0024331': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024331.jpg',
#  'ISIC_0024332': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024332.jpg',
#  'ISIC_0024333': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024333.jpg',
#  'ISIC_0024334': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024334.jpg',
#  'ISIC_0024335': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024335.jpg',
#  'ISIC_0024336': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024336.jpg',
#  'ISIC_0024337': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024337.jpg',
#  'ISIC_0024338': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024338.jpg',
#  'ISIC_0024339': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024339.jpg',
#  'ISIC_0024340': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024340.jpg',
#  'ISIC_0024341': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024341.jpg',
#  'ISIC_0024342': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024342.jpg',
#  'ISIC_0024343': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024343.jpg',
#  'ISIC_0024344': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024344.jpg',
#  'ISIC_0024345': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024345.jpg',
#  'ISIC_0024346': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024346.jpg',
#  'ISIC_0024347': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024347.jpg',
#  'ISIC_0024348': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024348.jpg',
#  'ISIC_0024349': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024349.jpg',
#  'ISIC_0024350': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024350.jpg',
#  'ISIC_0024351': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024351.jpg',
#  'ISIC_0024352': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024352.jpg',
#  'ISIC_0024353': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024353.jpg',
#  'ISIC_0024354': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024354.jpg',
#  'ISIC_0024355': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024355.jpg',
#  'ISIC_0024356': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024356.jpg',
#  'ISIC_0024357': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024357.jpg',
#  'ISIC_0024358': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024358.jpg',
#  'ISIC_0024359': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024359.jpg',
#  'ISIC_0024360': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024360.jpg',
#  'ISIC_0024361': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024361.jpg',
#  'ISIC_0024362': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024362.jpg',
#  'ISIC_0024363': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024363.jpg',
#  'ISIC_0024364': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024364.jpg',
#  'ISIC_0024365': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024365.jpg',
#  'ISIC_0024366': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024366.jpg',
#  'ISIC_0024367': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024367.jpg',
#  'ISIC_0024368': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024368.jpg',
#  'ISIC_0024369': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024369.jpg',
#  'ISIC_0024370': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024370.jpg',
#  'ISIC_0024371': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024371.jpg',
#  'ISIC_0024372': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024372.jpg',
#  'ISIC_0024373': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024373.jpg',
#  'ISIC_0024374': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024374.jpg',
#  'ISIC_0024375': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024375.jpg',
#  'ISIC_0024376': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024376.jpg',
#  'ISIC_0024377': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024377.jpg',
#  'ISIC_0024378': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024378.jpg',
#  'ISIC_0024379': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024379.jpg',
#  'ISIC_0024380': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024380.jpg',
#  'ISIC_0024381': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024381.jpg',
#  'ISIC_0024382': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024382.jpg',
#  'ISIC_0024383': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024383.jpg',
#  'ISIC_0024384': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024384.jpg',
#  'ISIC_0024385': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024385.jpg',
#  'ISIC_0024386': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024386.jpg',
#  'ISIC_0024387': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024387.jpg',
#  'ISIC_0024388': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024388.jpg',
#  'ISIC_0024389': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024389.jpg',
#  'ISIC_0024390': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024390.jpg',
#  'ISIC_0024391': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024391.jpg',
#  'ISIC_0024392': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024392.jpg',
#  'ISIC_0024393': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024393.jpg',
#  'ISIC_0024394': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024394.jpg',
#  'ISIC_0024395': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024395.jpg',
#  'ISIC_0024396': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024396.jpg',
#  'ISIC_0024397': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024397.jpg',
#  'ISIC_0024398': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024398.jpg',
#  'ISIC_0024399': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024399.jpg',
#  'ISIC_0024400': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024400.jpg',
#  'ISIC_0024401': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024401.jpg',
#  'ISIC_0024402': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024402.jpg',
#  'ISIC_0024403': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024403.jpg',
#  'ISIC_0024404': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024404.jpg',
#  'ISIC_0024405': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024405.jpg',
#  'ISIC_0024406': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024406.jpg',
#  'ISIC_0024407': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024407.jpg',
#  'ISIC_0024408': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024408.jpg',
#  'ISIC_0024409': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024409.jpg',
#  'ISIC_0024410': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024410.jpg',
#  'ISIC_0024411': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024411.jpg',
#  'ISIC_0024412': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024412.jpg',
#  'ISIC_0024413': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024413.jpg',
#  'ISIC_0024414': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024414.jpg',
#  'ISIC_0024415': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024415.jpg',
#  'ISIC_0024416': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024416.jpg',
#  'ISIC_0024417': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024417.jpg',
#  'ISIC_0024418': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024418.jpg',
#  'ISIC_0024419': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024419.jpg',
#  'ISIC_0024420': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024420.jpg',
#  'ISIC_0024421': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024421.jpg',
#  'ISIC_0024422': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024422.jpg',
#  'ISIC_0024423': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024423.jpg',
#  'ISIC_0024424': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024424.jpg',
#  'ISIC_0024425': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024425.jpg',
#  'ISIC_0024426': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024426.jpg',
#  'ISIC_0024427': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024427.jpg',
#  'ISIC_0024428': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024428.jpg',
#  'ISIC_0024429': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024429.jpg',
#  'ISIC_0024430': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024430.jpg',
#  'ISIC_0024431': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024431.jpg',
#  'ISIC_0024432': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024432.jpg',
#  'ISIC_0024433': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024433.jpg',
#  'ISIC_0024434': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024434.jpg',
#  'ISIC_0024435': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024435.jpg',
#  'ISIC_0024436': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024436.jpg',
#  'ISIC_0024437': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024437.jpg',
#  'ISIC_0024438': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024438.jpg',
#  'ISIC_0024439': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024439.jpg',
#  'ISIC_0024440': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024440.jpg',
#  'ISIC_0024441': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024441.jpg',
#  'ISIC_0024442': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024442.jpg',
#  'ISIC_0024443': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024443.jpg',
#  'ISIC_0024444': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024444.jpg',
#  'ISIC_0024445': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024445.jpg',
#  'ISIC_0024446': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024446.jpg',
#  'ISIC_0024447': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024447.jpg',
#  'ISIC_0024448': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024448.jpg',
#  'ISIC_0024449': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024449.jpg',
#  'ISIC_0024450': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024450.jpg',
#  'ISIC_0024451': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024451.jpg',
#  'ISIC_0024452': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024452.jpg',
#  'ISIC_0024453': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024453.jpg',
#  'ISIC_0024454': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024454.jpg',
#  'ISIC_0024455': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024455.jpg',
#  'ISIC_0024456': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024456.jpg',
#  'ISIC_0024457': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024457.jpg',
#  'ISIC_0024458': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024458.jpg',
#  'ISIC_0024459': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024459.jpg',
#  'ISIC_0024460': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024460.jpg',
#  'ISIC_0024461': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024461.jpg',
#  'ISIC_0024462': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024462.jpg',
#  'ISIC_0024463': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024463.jpg',
#  'ISIC_0024464': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024464.jpg',
#  'ISIC_0024465': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024465.jpg',
#  'ISIC_0024466': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024466.jpg',
#  'ISIC_0024467': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024467.jpg',
#  'ISIC_0024468': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024468.jpg',
#  'ISIC_0024469': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024469.jpg',
#  'ISIC_0024470': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024470.jpg',
#  'ISIC_0024471': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024471.jpg',
#  'ISIC_0024472': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024472.jpg',
#  'ISIC_0024473': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024473.jpg',
#  'ISIC_0024474': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024474.jpg',
#  'ISIC_0024475': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024475.jpg',
#  'ISIC_0024476': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024476.jpg',
#  'ISIC_0024477': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024477.jpg',
#  'ISIC_0024478': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024478.jpg',
#  'ISIC_0024479': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024479.jpg',
#  'ISIC_0024480': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024480.jpg',
#  'ISIC_0024481': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024481.jpg',
#  'ISIC_0024482': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024482.jpg',
#  'ISIC_0024483': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024483.jpg',
#  'ISIC_0024484': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024484.jpg',
#  'ISIC_0024485': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024485.jpg',
#  'ISIC_0024486': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024486.jpg',
#  'ISIC_0024487': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024487.jpg',
#  'ISIC_0024488': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024488.jpg',
#  'ISIC_0024489': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024489.jpg',
#  'ISIC_0024490': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024490.jpg',
#  'ISIC_0024491': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024491.jpg',
#  'ISIC_0024492': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024492.jpg',
#  'ISIC_0024493': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024493.jpg',
#  'ISIC_0024494': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024494.jpg',
#  'ISIC_0024495': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024495.jpg',
#  'ISIC_0024496': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024496.jpg',
#  'ISIC_0024497': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024497.jpg',
#  'ISIC_0024498': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024498.jpg',
#  'ISIC_0024499': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024499.jpg',
#  'ISIC_0024500': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024500.jpg',
#  'ISIC_0024501': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024501.jpg',
#  'ISIC_0024502': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024502.jpg',
#  'ISIC_0024503': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024503.jpg',
#  'ISIC_0024504': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024504.jpg',
#  'ISIC_0024505': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024505.jpg',
#  'ISIC_0024506': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024506.jpg',
#  'ISIC_0024507': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024507.jpg',
#  'ISIC_0024508': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024508.jpg',
#  'ISIC_0024509': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024509.jpg',
#  'ISIC_0024510': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024510.jpg',
#  'ISIC_0024511': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024511.jpg',
#  'ISIC_0024512': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024512.jpg',
#  'ISIC_0024513': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024513.jpg',
#  'ISIC_0024514': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024514.jpg',
#  'ISIC_0024515': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024515.jpg',
#  'ISIC_0024516': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024516.jpg',
#  'ISIC_0024517': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024517.jpg',
#  'ISIC_0024518': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024518.jpg',
#  'ISIC_0024519': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024519.jpg',
#  'ISIC_0024520': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024520.jpg',
#  'ISIC_0024521': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024521.jpg',
#  'ISIC_0024522': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024522.jpg',
#  'ISIC_0024523': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024523.jpg',
#  'ISIC_0024524': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024524.jpg',
#  'ISIC_0024525': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024525.jpg',
#  'ISIC_0024526': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024526.jpg',
#  'ISIC_0024527': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024527.jpg',
#  'ISIC_0024528': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024528.jpg',
#  'ISIC_0024529': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024529.jpg',
#  'ISIC_0024530': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024530.jpg',
#  'ISIC_0024531': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024531.jpg',
#  'ISIC_0024532': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024532.jpg',
#  'ISIC_0024533': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024533.jpg',
#  'ISIC_0024534': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024534.jpg',
#  'ISIC_0024535': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024535.jpg',
#  'ISIC_0024536': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024536.jpg',
#  'ISIC_0024537': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024537.jpg',
#  'ISIC_0024538': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024538.jpg',
#  'ISIC_0024539': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024539.jpg',
#  'ISIC_0024540': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024540.jpg',
#  'ISIC_0024541': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024541.jpg',
#  'ISIC_0024542': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024542.jpg',
#  'ISIC_0024543': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024543.jpg',
#  'ISIC_0024544': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024544.jpg',
#  'ISIC_0024545': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024545.jpg',
#  'ISIC_0024546': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024546.jpg',
#  'ISIC_0024547': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024547.jpg',
#  'ISIC_0024548': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024548.jpg',
#  'ISIC_0024549': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024549.jpg',
#  'ISIC_0024550': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024550.jpg',
#  'ISIC_0024551': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024551.jpg',
#  'ISIC_0024552': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024552.jpg',
#  'ISIC_0024553': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024553.jpg',
#  'ISIC_0024554': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024554.jpg',
#  'ISIC_0024555': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024555.jpg',
#  'ISIC_0024556': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024556.jpg',
#  'ISIC_0024557': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024557.jpg',
#  'ISIC_0024558': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024558.jpg',
#  'ISIC_0024559': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024559.jpg',
#  'ISIC_0024560': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024560.jpg',
#  'ISIC_0024561': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024561.jpg',
#  'ISIC_0024562': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024562.jpg',
#  'ISIC_0024563': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024563.jpg',
#  'ISIC_0024564': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024564.jpg',
#  'ISIC_0024565': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024565.jpg',
#  'ISIC_0024566': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024566.jpg',
#  'ISIC_0024567': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024567.jpg',
#  'ISIC_0024568': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024568.jpg',
#  'ISIC_0024569': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024569.jpg',
#  'ISIC_0024570': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024570.jpg',
#  'ISIC_0024571': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024571.jpg',
#  'ISIC_0024572': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024572.jpg',
#  'ISIC_0024573': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024573.jpg',
#  'ISIC_0024574': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024574.jpg',
#  'ISIC_0024575': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024575.jpg',
#  'ISIC_0024576': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024576.jpg',
#  'ISIC_0024577': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024577.jpg',
#  'ISIC_0024578': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024578.jpg',
#  'ISIC_0024579': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024579.jpg',
#  'ISIC_0024580': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024580.jpg',
#  'ISIC_0024581': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024581.jpg',
#  'ISIC_0024582': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024582.jpg',
#  'ISIC_0024583': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024583.jpg',
#  'ISIC_0024584': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024584.jpg',
#  'ISIC_0024585': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024585.jpg',
#  'ISIC_0024586': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024586.jpg',
#  'ISIC_0024587': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024587.jpg',
#  'ISIC_0024588': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024588.jpg',
#  'ISIC_0024589': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024589.jpg',
#  'ISIC_0024590': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024590.jpg',
#  'ISIC_0024591': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024591.jpg',
#  'ISIC_0024592': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024592.jpg',
#  'ISIC_0024593': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024593.jpg',
#  'ISIC_0024594': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024594.jpg',
#  'ISIC_0024595': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024595.jpg',
#  'ISIC_0024596': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024596.jpg',
#  'ISIC_0024597': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024597.jpg',
#  'ISIC_0024598': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024598.jpg',
#  'ISIC_0024599': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024599.jpg',
#  'ISIC_0024600': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024600.jpg',
#  'ISIC_0024601': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024601.jpg',
#  'ISIC_0024602': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024602.jpg',
#  'ISIC_0024603': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024603.jpg',
#  'ISIC_0024604': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024604.jpg',
#  'ISIC_0024605': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024605.jpg',
#  'ISIC_0024606': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024606.jpg',
#  'ISIC_0024607': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024607.jpg',
#  'ISIC_0024608': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024608.jpg',
#  'ISIC_0024609': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024609.jpg',
#  'ISIC_0024610': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024610.jpg',
#  'ISIC_0024611': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024611.jpg',
#  'ISIC_0024612': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024612.jpg',
#  'ISIC_0024613': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024613.jpg',
#  'ISIC_0024614': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024614.jpg',
#  'ISIC_0024615': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024615.jpg',
#  'ISIC_0024616': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024616.jpg',
#  'ISIC_0024617': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024617.jpg',
#  'ISIC_0024618': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024618.jpg',
#  'ISIC_0024619': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024619.jpg',
#  'ISIC_0024620': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024620.jpg',
#  'ISIC_0024621': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024621.jpg',
#  'ISIC_0024622': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024622.jpg',
#  'ISIC_0024623': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024623.jpg',
#  'ISIC_0024624': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024624.jpg',
#  'ISIC_0024625': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024625.jpg',
#  'ISIC_0024626': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024626.jpg',
#  'ISIC_0024627': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024627.jpg',
#  'ISIC_0024628': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024628.jpg',
#  'ISIC_0024629': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024629.jpg',
#  'ISIC_0024630': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024630.jpg',
#  'ISIC_0024631': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024631.jpg',
#  'ISIC_0024632': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024632.jpg',
#  'ISIC_0024633': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024633.jpg',
#  'ISIC_0024634': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024634.jpg',
#  'ISIC_0024635': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024635.jpg',
#  'ISIC_0024636': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024636.jpg',
#  'ISIC_0024637': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024637.jpg',
#  'ISIC_0024638': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024638.jpg',
#  'ISIC_0024639': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024639.jpg',
#  'ISIC_0024640': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024640.jpg',
#  'ISIC_0024641': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024641.jpg',
#  'ISIC_0024642': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024642.jpg',
#  'ISIC_0024643': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0024643.jpg',
# ...
#  'ISIC_0025194': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025194.jpg',
#  'ISIC_0025195': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025195.jpg',
#  'ISIC_0025196': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025196.jpg',
#  'ISIC_0025197': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025197.jpg',
#  'ISIC_0025198': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025198.jpg',
#  'ISIC_0025199': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025199.jpg',
#  'ISIC_0025200': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025200.jpg',
#  'ISIC_0025201': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025201.jpg',
#  'ISIC_0025202': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025202.jpg',
#  'ISIC_0025203': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025203.jpg',
#  'ISIC_0025204': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025204.jpg',
#  'ISIC_0025205': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025205.jpg',
#  'ISIC_0025206': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025206.jpg',
#  'ISIC_0025207': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025207.jpg',
#  'ISIC_0025208': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025208.jpg',
#  'ISIC_0025209': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025209.jpg',
#  'ISIC_0025210': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025210.jpg',
#  'ISIC_0025211': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025211.jpg',
#  'ISIC_0025212': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025212.jpg',
#  'ISIC_0025213': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025213.jpg',
#  'ISIC_0025214': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025214.jpg',
#  'ISIC_0025215': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025215.jpg',
#  'ISIC_0025216': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025216.jpg',
#  'ISIC_0025217': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025217.jpg',
#  'ISIC_0025218': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025218.jpg',
#  'ISIC_0025219': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025219.jpg',
#  'ISIC_0025220': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025220.jpg',
#  'ISIC_0025221': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025221.jpg',
#  'ISIC_0025222': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025222.jpg',
#  'ISIC_0025223': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025223.jpg',
#  'ISIC_0025224': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025224.jpg',
#  'ISIC_0025225': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025225.jpg',
#  'ISIC_0025226': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025226.jpg',
#  'ISIC_0025227': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025227.jpg',
#  'ISIC_0025228': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025228.jpg',
#  'ISIC_0025229': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025229.jpg',
#  'ISIC_0025230': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025230.jpg',
#  'ISIC_0025231': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025231.jpg',
#  'ISIC_0025232': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025232.jpg',
#  'ISIC_0025233': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025233.jpg',
#  'ISIC_0025234': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025234.jpg',
#  'ISIC_0025235': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025235.jpg',
#  'ISIC_0025236': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025236.jpg',
#  'ISIC_0025237': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025237.jpg',
#  'ISIC_0025238': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025238.jpg',
#  'ISIC_0025239': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025239.jpg',
#  'ISIC_0025240': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025240.jpg',
#  'ISIC_0025241': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025241.jpg',
#  'ISIC_0025242': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025242.jpg',
#  'ISIC_0025243': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025243.jpg',
#  'ISIC_0025244': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025244.jpg',
#  'ISIC_0025245': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025245.jpg',
#  'ISIC_0025246': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025246.jpg',
#  'ISIC_0025247': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025247.jpg',
#  'ISIC_0025248': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025248.jpg',
#  'ISIC_0025249': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025249.jpg',
#  'ISIC_0025250': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025250.jpg',
#  'ISIC_0025251': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025251.jpg',
#  'ISIC_0025252': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025252.jpg',
#  'ISIC_0025253': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025253.jpg',
#  'ISIC_0025254': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025254.jpg',
#  'ISIC_0025255': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025255.jpg',
#  'ISIC_0025256': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025256.jpg',
#  'ISIC_0025257': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025257.jpg',
#  'ISIC_0025258': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025258.jpg',
#  'ISIC_0025259': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025259.jpg',
#  'ISIC_0025260': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025260.jpg',
#  'ISIC_0025261': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025261.jpg',
#  'ISIC_0025262': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025262.jpg',
#  'ISIC_0025263': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025263.jpg',
#  'ISIC_0025264': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025264.jpg',
#  'ISIC_0025265': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025265.jpg',
#  'ISIC_0025266': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025266.jpg',
#  'ISIC_0025267': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025267.jpg',
#  'ISIC_0025268': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025268.jpg',
#  'ISIC_0025269': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025269.jpg',
#  'ISIC_0025270': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025270.jpg',
#  'ISIC_0025271': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025271.jpg',
#  'ISIC_0025272': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025272.jpg',
#  'ISIC_0025273': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025273.jpg',
#  'ISIC_0025274': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025274.jpg',
#  'ISIC_0025275': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025275.jpg',
#  'ISIC_0025276': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025276.jpg',
#  'ISIC_0025277': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025277.jpg',
#  'ISIC_0025278': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025278.jpg',
#  'ISIC_0025279': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025279.jpg',
#  'ISIC_0025280': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025280.jpg',
#  'ISIC_0025281': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025281.jpg',
#  'ISIC_0025282': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025282.jpg',
#  'ISIC_0025283': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025283.jpg',
#  'ISIC_0025284': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025284.jpg',
#  'ISIC_0025285': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025285.jpg',
#  'ISIC_0025286': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025286.jpg',
#  'ISIC_0025287': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025287.jpg',
#  'ISIC_0025288': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025288.jpg',
#  'ISIC_0025289': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025289.jpg',
#  'ISIC_0025290': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025290.jpg',
#  'ISIC_0025291': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025291.jpg',
#  'ISIC_0025292': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025292.jpg',
#  'ISIC_0025293': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025293.jpg',
#  'ISIC_0025294': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025294.jpg',
#  'ISIC_0025295': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025295.jpg',
#  'ISIC_0025296': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025296.jpg',
#  'ISIC_0025297': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025297.jpg',
#  'ISIC_0025298': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025298.jpg',
#  'ISIC_0025299': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025299.jpg',
#  'ISIC_0025300': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025300.jpg',
#  'ISIC_0025301': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025301.jpg',
#  'ISIC_0025302': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025302.jpg',
#  'ISIC_0025303': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025303.jpg',
#  'ISIC_0025304': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025304.jpg',
#  'ISIC_0025305': 'E:\\Research\\Research_Skin_Cancer\\Research_Skin_Cancer_Datasets\\HAM10000_IMG\\HAM10000_images_part_1\\ISIC_0025305.jpg',
#  ...}

# %%
img = skin_df.sample(n=75, random_state=1,replace=False)
img['image'] = img['path'].map(lambda x: np.asarray(Image.open(x).resize((100,75))))
#Image Sampling
n_samples = 3

fig, m_axs = plt.subplots(7, n_samples, figsize = (4*n_samples, 3*7))

for n_axs, (type_name, type_rows) in zip(m_axs,img.sort_values(['cell_type']).groupby('cell_type')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(n_samples, random_state=1234 ,replace = True).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')

# %%
basic_EDA(skin_df)
# Out:
# Number of Samples: 10015,
# Number of Features: 11,
# Duplicated Entries: 0,
# Null Entries: 57,
# Number of Rows with Null Entries: 57 0.6%

# %%
summary_table(skin_df)
# Out:
#              Name   dtypes  Missing  Uniques
# 0       lesion_id   object        0     7470
# 1        image_id   object        0    10015
# 2              dx   object        0        7
# 3         dx_type   object        0        4
# 4             age  float64       57       18
# 5             sex   object        0        3
# 6    localization   object        0       15
# 7         dataset   object        0        4
# 8            path   object        0    10015
# 9       cell_type   object        0        7
# 10  cell_type_idx     int8        0        7

# %%
countplot(skin_df,'dx_type', 'Diagnostic Type', 'Count', 'Samples per Type of Diagnosis')
countplot(skin_df,'cell_type', 'Type of Skin Lesion', 'Count', 'Samples per Type of Skin Lesion')
countplot(skin_df,'sex', 'Gender', 'Count', 'Samples per Gender')

# %%
skin_df['age'].fillna((skin_df['age'].mode()), inplace=True)

plt.figure(figsize=(20,8))
sns.set(style="ticks", font_scale = 1)
ax = sns.countplot(data = skin_df,x='age',palette="Blues_d")
sns.despine(top=True, right=True, left=True, bottom=False)
plt.xticks(rotation=0,fontsize = 12)
ax.set_xlabel('Age',fontsize = 14,weight = 'bold')
ax.set_ylabel('Count',fontsize = 14,weight = 'bold')
plt.title('Age Distribution', fontsize = 16,weight = 'bold');

# %%
skin_mel = skin_df.loc[:,['age','sex','localization','cell_type']]
skin_mel = skin_mel[skin_mel['cell_type'] == 'Melanoma']

countplot(skin_mel,'sex', 'Gender', 'Count', 'Melanoma - Malignant Cancer per Gender')

# %%
plt.figure(figsize=(20,8))
sns.set(style="ticks", font_scale = 1)
ax = sns.countplot(data = skin_mel,x='age',palette="Blues_d", hue = 'sex')
sns.despine(top=True, right=True, left=True, bottom=False)
plt.xticks(rotation=0,fontsize = 12)
ax.set_xlabel('Age',fontsize = 14,weight = 'bold')
ax.set_ylabel('Count',fontsize = 14,weight = 'bold')
plt.title('Age Distribution - Melanoma', fontsize = 16,weight = 'bold');

# %%
skin_local = skin_mel.groupby(['localization']).size().sort_values(ascending=False, inplace=False).reset_index()
skin_local.columns = ['localization', 'count']
sort_by = skin_local['localization']

skin_heat = skin_mel.groupby(['age','localization']).size().reset_index()
skin_heat.columns = ['age', 'localization', 'count']
skin_heat.sort_values('count', ascending=False, inplace=True)

def heatmap(df, index,columns,values,vmax,sort_by,Title):
    df_wide = df.pivot(index=index, columns=columns, values=values)
    df_wide = df_wide.reindex(index=sort_by)
    plt.figure(figsize=(12,8))
    ax = sns.heatmap(df_wide, annot=True, fmt='.0f', yticklabels='auto', cmap=sns.color_palette("YlGnBu", as_cmap=True), center=.2,vmin = 0, vmax = vmax,linewidths=.5)
    ax.xaxis.tick_top() # x axis on top
    ax.xaxis.set_label_position('top')
    ax.set_xlabel(columns,fontsize = 14,weight = 'bold')
    ax.set_ylabel(index,fontsize = 14,weight = 'bold')    
    ax.set_title(Title,fontsize = 16,weight = 'bold',pad=20)
    plt.show()
    
heatmap(skin_heat,'localization', 'age','count', 20,sort_by,'Age and Localization of Melanomas')

# %%
skin_df['image'] = skin_df['path'].map(lambda x: np.asarray(Image.open(x).resize((100,75))))

features=skin_df.drop(columns=['cell_type_idx'],axis=1)
target=skin_df['cell_type_idx']

# %%
# Create First Train and Test sets
x_train_o, x_test_o, y_train_o, y_test_o = train_test_split(features, target, test_size=0.20,random_state=123)

#The normalisation is done using the training set Mean and Std. Deviation as reference
x_train = np.asarray(x_train_o['image'].tolist())
x_test = np.asarray(x_test_o['image'].tolist())

x_train_mean = np.mean(x_train)
x_train_std = np.std(x_train)

x_train = (x_train - x_train_mean)/x_train_std
x_test = (x_test - x_train_mean)/x_train_std

# Perform one-hot encoding on the labels
y_train = utils.to_categorical(y_train_o, num_classes = 7)
y_test = utils.to_categorical(y_test_o, num_classes = 7)

#Splitting training into Train and Validatation sets
x_train, x_validate, y_train, y_validate = train_test_split(x_train, y_train, test_size = 0.1,random_state=123)

#Reshaping the Images into 3 channels (RGB)
x_train = x_train.reshape(x_train.shape[0], *(75, 100, 3))
x_test = x_test.reshape(x_test.shape[0], *(75, 100, 3))
x_validate = x_validate.reshape(x_validate.shape[0], *(75, 100, 3))

# %% [markdown]
# # CNN Implementation

# %%
#Model Parameters
input_shape = (75, 100, 3)
num_classes = 7

optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)

epochs = 100
batch_size = 20

#Callbacks
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', patience=5, verbose=0, factor=0.5, min_lr=0.00001)
early_stopping_monitor = EarlyStopping(patience=20,monitor='val_accuracy')

#Data Augmentation
dataaugment = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=90,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=True,  # randomly flip images
        vertical_flip=True,  # randomly flip images
        shear_range = 10) 

dataaugment.fit(x_train)

def history(model):
    model.compile(optimizer = optimizer , loss = "categorical_crossentropy", metrics=["accuracy"])
    history = model.fit(dataaugment.flow(x_train,y_train, batch_size=batch_size),
                        epochs = epochs, validation_data = (x_validate,y_validate),
                        verbose = 0, steps_per_epoch=x_train.shape[0] // batch_size, 
                        callbacks=[learning_rate_reduction,early_stopping_monitor])

    loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
    predictions = model.predict(x_test)
    loss_v, accuracy_v = model.evaluate(x_validate, y_validate, verbose=0)
    loss_t, accuracy_t = model.evaluate(x_train, y_train, verbose=0)
    return (predictions,accuracy_t,accuracy_v,accuracy)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',padding = 'Same',input_shape=input_shape))
model.add(BatchNormalization())
##############################
model.add(Conv2D(64, (3, 3), activation='relu',padding = 'Same'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size = (2, 2)))
model.add(Dropout(0.025))

model.add(Conv2D(64, (3, 3), activation='relu',padding = 'Same'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), activation='relu',padding = 'Same'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=(2, 2)))
model.add(Dropout(0.025))
##############################
model.add(Conv2D(64, (3, 3), activation='relu',padding = 'Same'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size = (2, 2)))
model.add(Dropout(0.025))

model.add(Conv2D(64, (3, 3), activation='relu',padding = 'Same'))
model.add(BatchNormalization())

model.add(Conv2D(64, (3, 3), activation='relu',padding = 'Same'))
model.add(BatchNormalization())
model.add(AveragePooling2D(pool_size=(2, 2)))
model.add(Dropout(0.025))
##############################

model.add(Flatten())

model.add(BatchNormalization())
model.add(Dense(128, activation='relu'))
model.add(Activation('relu'))
model.add(Dropout(0.025))

#Output
model.add(BatchNormalization())
model.add(Dense(num_classes, activation='softmax'))

y_pred, accuracy_t,accuracy_v,accuracy = history(model)
print("Training: accuracy = %f" % (accuracy_t))
print("Validation: accuracy = %f" % (accuracy_v))
print("Test: accuracy = %f" % (accuracy))
# Out:
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Training: accuracy = 0.846602
# Validation: accuracy = 0.783042
# Test: accuracy = 0.774838

# %% [markdown]
# # ResNet50

# %%
base_model = ResNet50(include_top=False, input_shape=(75,100, 3),pooling = 'avg', weights = 'imagenet');

ResNet50model = Sequential()
ResNet50model.add(base_model)
ResNet50model.add(Dropout(0.2))
ResNet50model.add(Dense(128, activation="relu"))
ResNet50model.add(Dropout(0.2))
ResNet50model.add(Dense(num_classes, activation = 'softmax'))
###################################

for layer in base_model.layers:
    layer.trainable = True

ResNet50y_pred,ResNet50accuracy_t,ResNet50accuracy_v,ResNet50accuracy = history(ResNet50model)
    
print("ResNet50 Training: accuracy = %f" % (ResNet50accuracy_t))
print("ResNet50 Validation: accuracy = %f" % (ResNet50accuracy_v))
print("ResNet50 Test: accuracy = %f" % (ResNet50accuracy))
# Out:
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# ResNet50 Training: accuracy = 0.779057
# ResNet50 Validation: accuracy = 0.726933
# ResNet50 Test: accuracy = 0.722416

# %% [markdown]
# # XCeption

# %%
training_shape = (75,100, 3)
base_model = Xception(include_top=False,weights='imagenet',input_shape = training_shape)

XCeptionmodel = base_model.output
XCeptionmodel = Flatten()(XCeptionmodel)

XCeptionmodel = BatchNormalization()(XCeptionmodel)
XCeptionmodel = Dense(128, activation='relu')(XCeptionmodel)
XCeptionmodel = Dropout(0.2)(XCeptionmodel)

XCeptionmodel = BatchNormalization()(XCeptionmodel)
XCeptionoutput = Dense(num_classes, activation = 'softmax')(XCeptionmodel)
XCeptionmodel = Model(inputs=base_model.input, outputs=XCeptionoutput)

for layer in base_model.layers:
    layer.trainable = True

XCeptiony_pred,XCeptionaccuracy_t,XCeptionaccuracy_v,XCeptionaccuracy = history(XCeptionmodel)
    
print("XCeption Training: accuracy = %f" % (XCeptionaccuracy_t))
print("XCeption Validation: accuracy = %f" % (XCeptionaccuracy_v))
print("XCeption Test: accuracy = %f" % (XCeptionaccuracy))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - ETA:  - 14s 0us/step
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# WARNING:tensorflow:Reduce LR on plateau conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# XCeption Training: accuracy = 0.950763
# XCeption Validation: accuracy = 0.852868
# XCeption Test: accuracy = 0.839241

# %% [markdown]
# # Result and Conclusion

# %%
predictions = np.array(list(map(lambda x: np.argmax(x), XCeptiony_pred)))
categories = ['Actinic keratoses', 'Basal cell carcinoma',
              'Benign keratosis-like lesions ', 
              'Dermatofibroma', 
              'Melanocytic nevi',
              'Melanoma', 
              'Vascular lesions']

CMatrix = pd.DataFrame(confusion_matrix(y_test_o, predictions), columns=categories, index =categories)

plt.figure(figsize=(12, 6))
ax = sns.heatmap(CMatrix, annot = True, fmt = 'g' ,vmin = 0, vmax = 20,cmap = 'Blues')
ax.set_xlabel('Predicted',fontsize = 14,weight = 'bold')
ax.set_xticklabels(ax.get_xticklabels(),rotation =90);
ax.set_ylabel('Actual',fontsize = 14,weight = 'bold')    
ax.set_title('Confusion Matrix - Test Set',fontsize = 16,weight = 'bold',pad=20);

# %%
print("The End")
# Out:
# The End
